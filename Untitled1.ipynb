# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Importing data
df = pd.read_csv('Hotel Reservations.csv')
df.columns

df.booking_status.replace('Not_Canceled',0, inplace=True)
df.booking_status.replace('Canceled',1, inplace=True)
#df.booking_status.replace(0, 'Not_Canceled', inplace=True)
#df.booking_status.replace(1, 'Canceled', inplace=True)
df.dtypes

#visualizing correlations
correlations = df.corr(numeric_only=True).booking_status
correlations = correlations.abs().sort_values(ascending=False)
print(correlations)
ax = correlations.plot(kind='bar')
ax.set(ylim=[0, 1], ylabel='pearson correlation')
# Out:
# booking_status                          1.000000
# lead_time                               0.438538
# no_of_special_requests                  0.253070
# arrival_year                            0.179529
# avg_price_per_room                      0.142569
# repeated_guest                          0.107287
# no_of_week_nights                       0.092996
# no_of_adults                            0.086920
# required_car_parking_space              0.086185
# no_of_weekend_nights                    0.061563
# no_of_previous_bookings_not_canceled    0.060179
# no_of_previous_cancellations            0.033728
# no_of_children                          0.033078
# arrival_month                           0.011233
# arrival_date                            0.010629
# Name: booking_status, dtype: float64
# [(0.0, 1.0), Text(0, 0.5, 'pearson correlation')]

# %%
df_features
# Out:
#        booking_status  lead_time  no_of_special_requests  arrival_year  \
# 0                   0        224                       0          2017
# 1                   0          5                       1          2018
# 2                   1          1                       0          2018
# 3                   1        211                       0          2018
# 4                   1         48                       0          2018
# ...               ...        ...                     ...           ...
# 36270               0         85                       1          2018
# 36271               1        228                       2          2018
# 36272               0        148                       2          2018
# 36273               1         63                       0          2018
# 36274               0        207                       0          2018
#
#        avg_price_per_room  repeated_guest
# 0                   65.00               0
# 1                  106.68               0
# 2                   60.00               0
# 3                  100.00               0
# 4                   94.50               0
# ...                   ...             ...
# 36270              167.80               0
# 36271               90.95               0
# 36272               98.39               0
# 36273               94.50               0
# 36274              161.67               0
#
# [36275 rows x 6 columns]

# %%
features = correlations.index[:6]
df_features = df[features]
df_features

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5))

sns.boxplot(x=df_features.booking_status, y=df.lead_time, ax=ax1)
sns.boxplot(x=df_features.booking_status, y=df.avg_price_per_room, ax=ax2)
sns.boxplot(x=df_features.booking_status, y=df.arrival_month, ax=ax3)

# display the plots
plt.show()
